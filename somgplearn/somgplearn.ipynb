# %% [markdown]
# # Integrating Sympy into GPlearn
#
# This is a test script to see if the implenetation. However the implement wasnt successful due to incompatiable issues. The issue is elaborated more specifically on the project paper and read me

# %%
#loading packages & dependencies
#When the %pylab magic function is entered at the IPython prompt, it triggers the import of various modules within Matplotlib.
# %pylab inline 
from somgplearn.genetic import SymbolicRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.utils.random import check_random_state
from mpl_toolkits.mplot3d import Axes3D
from sympy import *
import matplotlib.pyplot as plt
import numpy as np
import graphviz
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Ground truth
x0 = np.arange(-1, 1, .1)
x1 = np.arange(-1, 1, .1)
x0, x1 = np.meshgrid(x0, x1)
y_truth = x0**3+ 4*x1 - 0.75 #true function

ax = plt.figure().gca(projection='3d')
ax.set_xlim(-1, 1)
ax.set_ylim(-1, 1)
ax.set_xticks(np.arange(-1, 1.01, .5))
ax.set_yticks(np.arange(-1, 1.01, .5))
surf = ax.plot_surface(x0, x1, y_truth, rstride=1, cstride=1, color='red', alpha=0.4)
plt.show()

# %%
rng = check_random_state(0)

# Training samples
X_train = rng.uniform(-1, 1, 100).reshape(50, 2)
y_train = X_train[:, 0]**3+ 4*X_train[:, 1] - 0.75

# Testing samples|
X_test = rng.uniform(-1, 1, 100).reshape(50, 2)
y_test = X_test[:, 0]**3+ 4*X_test[:, 1] - 0.75

# %%
est_gp = SymbolicRegressor(population_size=5, #the number of programs in each generation
                           generations=30, stopping_criteria=0.01, #The required metric value required in order to stop evolution early.
                           p_crossover=0.7, p_subtree_mutation=0.1,
                           p_hoist_mutation=0.05, #0.05, The probability of performing hoist mutation on a tournament winner. Hoist mutation takes the winner of a tournament and selects a random subtree from it. A random subtree of that subtree is then selected and this is ‘hoisted’ into the original subtrees location to form an offspring in the next generation. This method helps to control bloat.
                           p_point_mutation=0.1,
                           max_samples=0.9, verbose=1,
                           parsimony_coefficient=0.01, random_state=0)
est_gp.fit(X_train, y_train)
# Out:
#     |   Population Average    |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
# hello world
# <class 'list'>
# C:\Users\taryar\anaconda3\lib\site-packages\sympy\core\sympify.py:456: SymPyDeprecationWarning:
#
# String fallback in sympify has been deprecated since SymPy 1.6. Use
# sympify(str(obj)) or sympy.core.sympify.converter or obj._sympy_
# instead. See https://github.com/sympy/sympy/issues/18066 for more
# info.
#
#   SymPyDeprecationWarning(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: Error from parse_expr with transformed code: "Function ('mul' )(Function ('add' )(Function ('mul' )(div (div (Symbol ('X1' ),Symbol ('X1' )),Symbol ('X1' )),Function ('add' )(Function ('sub' )(-Float ('0.285' ),Symbol ('X1' )),Function ('add' )(Symbol ('X0' ),Symbol ('X0' )))),div (Symbol ('X0' ),Float ('0.059' ))),div (div (Function ('sub' )(Function ('mul' )(-Float ('0.900' ),Symbol ('X0' )),Function ('sub' )(Symbol ('X1' ),Symbol ('X1' ))),Symbol ('X0' )),Function ('mul' )(div (div (-Float ('0.701' ),Float ('0.373' )),Function ('mul' )(-Float ('0.691' ),Symbol ('X1' ))),Function ('mul' )(Function ('sub' )(-Float ('0.368' ),Symbol ('X0' )),div (Symbol ('X1' ),Symbol ('X1' ))))))"
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-5ac2ec53548c> in <module>
#       6                            max_samples=0.9, verbose=1,
#       7                            parsimony_coefficient=0.01, random_state=0)
# ----> 8 est_gp.fit(X_train, y_train)
#
# ~\Desktop\somgplearn\somgplearn\genetic.py in fit(self, X, y, sample_weight)
#     532             for i in range(len1):
#     533                 for j in range(len(population[i])):
# --> 534                     print(simplify(population[i][j]))
#     535
#     536
#
# ~\anaconda3\lib\site-packages\sympy\simplify\simplify.py in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     577         return shorter(rv, collect_abs(rv))
#     578
# --> 579     expr = sympify(expr, rational=rational)
#     580     kwargs = dict(
#     581         ratio=kwargs.get('ratio', ratio),
#
# ~\anaconda3\lib\site-packages\sympy\core\sympify.py in sympify(a, locals, convert_xor, strict, rational, evaluate)
#     477     try:
#     478         a = a.replace('\n', '')
# --> 479         expr = parse_expr(a, local_dict=locals, transformations=transformations, evaluate=evaluate)
#     480     except (TokenError, SyntaxError) as exc:
#     481         raise SympifyError('could not parse %r' % a, exc)
#
# ~\anaconda3\lib\site-packages\sympy\parsing\sympy_parser.py in parse_expr(s, local_dict, transformations, global_dict, evaluate)
#    1016         return eval_expr(code, local_dict, global_dict)
#    1017     except Exception as e:
# -> 1018         raise e from ValueError(f"Error from parse_expr with transformed code: {code!r}")
#    1019
#    1020
#
# ~\anaconda3\lib\site-packages\sympy\parsing\sympy_parser.py in parse_expr(s, local_dict, transformations, global_dict, evaluate)
#    1014
#    1015     try:
# -> 1016         return eval_expr(code, local_dict, global_dict)
#    1017     except Exception as e:
#    1018         raise e from ValueError(f"Error from parse_expr with transformed code: {code!r}")
#
# ~\anaconda3\lib\site-packages\sympy\parsing\sympy_parser.py in eval_expr(code, local_dict, global_dict)
#     908     Generally, ``parse_expr`` should be used.
#     909     """
# --> 910     expr = eval(
#     911         code, global_dict, local_dict)  # take local objects in preference
#     912     return expr
#
# <string> in <module>
#
# ~\anaconda3\lib\site-packages\sympy\polys\polytools.py in div(f, g, *gens, **args)
#    4812
#    4813     try:
# -> 4814         (F, G), opt = parallel_poly_from_expr((f, g), *gens, **args)
#    4815     except PolificationFailed as exc:
#    4816         raise ComputationFailed('div', 2, exc)
#
# ~\anaconda3\lib\site-packages\sympy\polys\polytools.py in parallel_poly_from_expr(exprs, *gens, **args)
#    4338     """Construct polynomials from expressions. """
#    4339     opt = options.build_options(gens, args)
# -> 4340     return _parallel_poly_from_expr(exprs, opt)
#    4341
#    4342
#
# ~\anaconda3\lib\site-packages\sympy\polys\polytools.py in _parallel_poly_from_expr(exprs, opt)
#    4377
#    4378                 if opt.expand:
# -> 4379                     expr = expr.expand()
#    4380         else:
#    4381             failed = True
#
# AttributeError: 'Tuple' object has no attribute 'expand'

# %%
print(est_gp._program)

# %%
type(est_gp._program)

# %%
sim = simplify(str(est_gp._program))
print(sim)

# %%
y_gp = est_gp.predict(np.c_[x0.ravel(), x1.ravel()]).reshape(x0.shape)
score_gp = est_gp.score(X_test, y_test)
y_sim = 4.04858299595142*x1 - ( 0.716 - x0**3 )
#y_tree = est_tree.predict(np.c_[x0.ravel(), x1.ravel()]).reshape(x0.shape)
#score_tree = est_tree.score(X_test, y_test)
#y_rf = est_rf.predict(np.c_[x0.ravel(), x1.ravel()]).reshape(x0.shape)
#score_rf = est_rf.score(X_test, y_test)

fig = plt.figure(figsize=(12, 10))

for i, (y, score, title) in enumerate([(y_truth, None, "Ground Truth"),
                                       (y_gp, score_gp, "SymbolicRegressor"),
                                      (y_sim, None, "SymbolicSimplify")]):
                                       #(y_tree, score_tree, "DecisionTreeRegressor"),
                                       #(y_rf, score_rf, "RandomForestRegressor")]):

    ax = fig.add_subplot(2, 2, i+1, projection='3d')
    ax.set_xlim(-1, 1)
    ax.set_ylim(-1, 1)
    ax.set_xticks(np.arange(-1, 1.01, .5))
    ax.set_yticks(np.arange(-1, 1.01, .5))
    surf = ax.plot_surface(x0, x1, y, rstride=1, cstride=1, color='red', alpha=0.4)
    points = ax.scatter(X_train[:, 0], X_train[:, 1], y_train)
    if score is not None:
        score = ax.text(-.7, 0.1, .1, "$R^2 =\/ %.6f$" % score, 'x', fontsize=14)
    plt.title(title)

plt.show()
